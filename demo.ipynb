# %%
# !git clone https://github.com/armitakamari/cifar10-gradcam.git
# %cd cifar10-gradcam
# !pip install -r requirements.txt
# !python main.py

# %%
import os
from IPython.display import Image, display

results_files = [
    "results/loss_curve.png",
    "results/accuracy_curve.png",
    "results/confusion_matrix.png",
    "results/gradcam_correct.png",
    "results/gradcam_misclassified.png"
]

for img_path in results_files:
    if os.path.exists(img_path):
        print(f"--- {img_path} ---")
        display(Image(img_path))
